# %%
# !pip install keras-preprocessing
# Out:
# Collecting keras-preprocessing
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras-preprocessing) (1.25.2)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from keras-preprocessing) (1.16.0)
# Installing collected packages: keras-preprocessing
# Successfully installed keras-preprocessing-1.1.2

# %%
# System libraries
from pathlib import Path
import os.path
import random
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import cv2
from sklearn.model_selection import train_test_split
from keras_preprocessing.image import ImageDataGenerator
import tensorflow as tf
from tensorflow.keras import layers,models
from tensorflow.keras.callbacks import Callback, EarlyStopping,ModelCheckpoint, ReduceLROnPlateau
from keras.layers import Dense, Dropout
from tensorflow.keras import Model
from tensorflow.keras.optimizers import Adam
# Metrics
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.cm as cm

# %%
# !pip install ImageDataGenerator
# Out:
# ERROR: Could not find a version that satisfies the requirement ImageDataGenerator (from versions: none)
# ERROR: No matching distribution found for ImageDataGenerator

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def walk_through_dir(dir_path):
    for dirpath, dirnames, filenames in os.walk(dir_path):
        print(f"There are {len(dirnames)} directories and {len(filenames)} images in '{dirpath}'.")
dataset = "/content/drive/MyDrive/Birds_data/train"
walk_through_dir(dataset);
# Out:
# There are 10 directories and 0 images in '/content/drive/MyDrive/Birds_data/train'.
# There are 0 directories and 132 images in '/content/drive/MyDrive/Birds_data/train/ALBATROSS'.
# There are 0 directories and 160 images in '/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL'.
# There are 0 directories and 154 images in '/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO'.
# There are 0 directories and 195 images in '/content/drive/MyDrive/Birds_data/train/RAZORBILL'.
# There are 0 directories and 207 images in '/content/drive/MyDrive/Birds_data/train/RED TAILED HAWK'.
# There are 0 directories and 164 images in '/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD'.
# There are 0 directories and 187 images in '/content/drive/MyDrive/Birds_data/train/AFRICAN PIED HORNBILL'.
# There are 0 directories and 176 images in '/content/drive/MyDrive/Birds_data/train/GOLDEN CHEEKED WARBLER'.
# There are 0 directories and 170 images in '/content/drive/MyDrive/Birds_data/train/AMERICAN BITTERN'.
# There are 0 directories and 150 images in '/content/drive/MyDrive/Birds_data/train/MYNA'.

# %%
image_dir = Path(dataset)

# Get filepaths and labels
filepaths = list(image_dir.glob(r'**/*.JPG')) + list(image_dir.glob(r'**/*.jpg')) + list(image_dir.glob(r'**/*.png')) + list(image_dir.glob(r'**/*.png'))

# %%
filepaths
# Out:
# [PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/005.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/001.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/002.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/004.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/003.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/033.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/024.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/035.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/022.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/014.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/018.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/010.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/031.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/017.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/016.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/025.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/012.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/023.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/015.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/027.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/028.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/029.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/030.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/020.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/011.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/019.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/034.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/021.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/013.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/026.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/008.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/009.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/007.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/006.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/032.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/056.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/039.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/053.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/058.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/049.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/050.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/055.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/038.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/040.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/041.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/045.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/036.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/044.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/048.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/052.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/054.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/057.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/051.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/063.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/065.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/043.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/064.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/062.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/059.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/042.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/037.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/046.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/047.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/060.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/061.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/079.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/082.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/066.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/088.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/086.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/090.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/070.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/091.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/073.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/074.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/069.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/092.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/077.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/083.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/085.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/080.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/078.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/071.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/068.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/093.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/076.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/075.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/094.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/067.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/084.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/072.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/087.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/095.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/081.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/089.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/105.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/126.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/106.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/112.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/107.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/122.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/124.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/113.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/111.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/109.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/098.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/117.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/110.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/099.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/108.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/115.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/096.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/103.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/119.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/116.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/121.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/125.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/102.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/118.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/097.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/104.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/101.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/123.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/100.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/120.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/114.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/131.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/130.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/128.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/129.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/127.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/ALBATROSS/132.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/004.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/002.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/006.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/007.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/005.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/001.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/003.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/015.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/023.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/024.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/016.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/010.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/020.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/011.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/012.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/018.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/022.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/008.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/014.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/013.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/019.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/009.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/021.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/017.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/030.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/040.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/037.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/039.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/035.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/032.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/028.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/029.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/026.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/027.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/038.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/031.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/036.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/033.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/034.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/025.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/047.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/048.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/051.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/052.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/042.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/046.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/045.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/055.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/041.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/050.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/054.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/043.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/057.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/053.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/044.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/056.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/049.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/064.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/065.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/067.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/070.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/068.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/061.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/060.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/059.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/074.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/062.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/058.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/066.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/063.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/069.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/072.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/071.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/073.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/075.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/085.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/078.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/083.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/088.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/089.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/090.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/087.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/091.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/084.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/076.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/081.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/077.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/080.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/086.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/079.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/082.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/098.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/103.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/105.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/100.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/095.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/097.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/102.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/107.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/093.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/104.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/106.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/108.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/101.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/094.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/099.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/096.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/092.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/124.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/110.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/123.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/113.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/117.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/118.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/122.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/109.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/121.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/119.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/116.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/120.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/115.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/114.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/112.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/111.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/140.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/125.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/142.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/138.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/133.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/139.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/130.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/126.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/137.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/131.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/128.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/136.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/132.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/141.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/129.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/127.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/135.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/134.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/147.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/156.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/153.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/149.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/150.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/148.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/144.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/143.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/145.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/155.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/154.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/151.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/158.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/146.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/152.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/157.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/160.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/LONG-EARED OWL/159.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/012.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/015.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/007.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/008.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/022.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/006.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/002.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/016.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/001.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/018.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/021.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/010.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/020.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/004.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/005.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/014.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/009.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/011.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/019.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/013.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/003.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/017.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/037.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/036.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/027.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/035.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/046.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/041.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/034.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/024.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/051.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/042.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/028.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/031.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/030.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/032.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/044.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/026.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/043.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/040.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/023.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/029.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/025.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/045.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/049.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/047.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/050.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/033.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/038.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/048.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/039.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/055.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/058.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/067.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/072.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/078.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/076.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/060.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/080.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/063.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/061.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/081.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/057.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/066.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/079.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/059.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/073.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/053.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/074.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/071.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/056.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/068.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/075.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/052.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/069.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/054.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/070.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/077.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/062.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/064.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/065.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/098.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/102.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/084.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/107.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/100.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/099.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/086.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/106.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/104.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/094.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/085.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/091.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/105.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/090.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/103.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/095.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/083.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/093.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/092.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/087.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/097.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/089.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/082.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/088.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/096.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/101.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/116.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/118.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/121.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/128.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/120.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/112.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/115.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/129.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/125.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/119.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/108.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/114.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/109.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/113.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/111.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/127.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/122.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/124.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/126.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/117.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/110.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/123.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/142.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/133.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/143.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/154.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/145.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/131.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/137.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/132.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/150.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/141.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/152.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/151.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/149.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/138.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/130.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/135.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/147.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/140.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/136.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/153.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/144.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/148.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/139.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/146.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/AFRICAN EMERALD CUCKOO/134.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/002.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/005.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/004.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/003.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/001.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/012.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/007.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/013.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/006.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/010.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/009.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/016.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/011.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/014.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/008.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/015.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/021.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/019.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/025.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/026.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/027.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/018.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/023.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/024.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/017.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/022.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/020.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/037.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/030.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/031.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/035.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/033.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/032.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/036.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/034.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/028.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/029.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/047.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/044.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/041.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/043.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/038.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/048.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/040.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/042.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/045.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/046.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/039.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/055.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/057.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/054.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/053.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/051.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/056.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/049.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/050.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/052.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/058.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/066.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/063.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/069.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/059.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/067.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/061.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/065.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/064.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/060.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/068.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/062.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/070.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/077.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/075.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/071.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/078.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/074.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/076.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/072.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/073.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/079.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/088.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/089.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/081.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/085 (1).jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/085.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/080.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/087.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/083.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/086.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/090.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/084 (1).jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/084.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/082.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/093.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/098.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/097.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/092.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/094.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/091.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/099.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/096.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/095.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/100.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/104.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/102.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/105.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/108.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/110.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/106.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/111.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/107.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/103.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/113.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/112.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/101.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/109.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/120.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/125.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/122.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/126.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/127.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/119.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/129.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/115.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/118.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/121.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/128.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/114.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/116.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/117.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/123.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/124.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/130.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/133.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/137.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/132.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/134.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/139.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/131.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/135.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/138.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/136.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/140.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/147.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/151.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/141.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/149.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/145.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/150.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/148.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/143.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/146.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/142.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/144.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/161.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/160.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/159.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/156.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/155.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/152.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/158.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/153.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/157.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/154.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/169.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/172.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/164.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/168.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/162.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/166.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/167.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/171.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/163.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RAZORBILL/165.jpg'),
# ...
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RED TAILED HAWK/146.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RED TAILED HAWK/159.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RED TAILED HAWK/154.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RED TAILED HAWK/152.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RED TAILED HAWK/149.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RED TAILED HAWK/148.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RED TAILED HAWK/160.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RED TAILED HAWK/158.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RED TAILED HAWK/177.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RED TAILED HAWK/178.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RED TAILED HAWK/175.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RED TAILED HAWK/179.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RED TAILED HAWK/167.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RED TAILED HAWK/165.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RED TAILED HAWK/170.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RED TAILED HAWK/172.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RED TAILED HAWK/162.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RED TAILED HAWK/171.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RED TAILED HAWK/163.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RED TAILED HAWK/168.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RED TAILED HAWK/166.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RED TAILED HAWK/173.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RED TAILED HAWK/164.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RED TAILED HAWK/176.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RED TAILED HAWK/169.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RED TAILED HAWK/174.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RED TAILED HAWK/190.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RED TAILED HAWK/195.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RED TAILED HAWK/185.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RED TAILED HAWK/193.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RED TAILED HAWK/187.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RED TAILED HAWK/188.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RED TAILED HAWK/184.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RED TAILED HAWK/192.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RED TAILED HAWK/182.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RED TAILED HAWK/180.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RED TAILED HAWK/181.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RED TAILED HAWK/191.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RED TAILED HAWK/186.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RED TAILED HAWK/194.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RED TAILED HAWK/189.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RED TAILED HAWK/196.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RED TAILED HAWK/183.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RED TAILED HAWK/198.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RED TAILED HAWK/197.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RED TAILED HAWK/202.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RED TAILED HAWK/200.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RED TAILED HAWK/201.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RED TAILED HAWK/199.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RED TAILED HAWK/2.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RED TAILED HAWK/4.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RED TAILED HAWK/1.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RED TAILED HAWK/3.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/RED TAILED HAWK/5.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/010.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/007.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/011.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/002.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/009.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/003.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/004.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/005.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/001.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/008.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/006.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/038.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/037.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/012.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/014.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/032.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/025.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/018.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/015.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/034.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/023.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/029.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/031.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/035.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/013.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/027.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/024.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/016.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/036.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/017.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/021.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/019.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/028.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/020.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/030.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/026.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/039.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/022.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/033.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/050.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/049.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/059.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/046.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/040.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/053.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/063.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/067.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/058.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/047.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/045.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/043.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/052.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/056.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/048.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/055.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/068.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/062.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/051.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/060.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/044.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/064.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/061.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/041.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/066.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/057.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/042.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/065.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/054.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/074.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/096.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/097.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/075.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/094.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/098.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/083.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/087.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/088.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/070.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/089.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/078.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/090.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/095.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/085.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/082.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/091.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/086.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/073.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/077.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/081.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/092.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/080.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/093.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/076.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/084.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/071.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/069.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/072.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/079.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/113.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/122.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/126.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/103.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/114.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/112.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/107.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/109.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/119.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/115.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/104.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/108.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/111.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/102.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/116.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/099.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/118.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/105.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/120.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/101.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/125.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/123.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/127.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/110.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/106.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/100.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/117.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/121.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/124.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/129.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/153.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/152.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/154.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/155.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/133.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/148.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/151.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/140.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/135.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/142.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/147.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/156.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/143.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/130.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/137.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/141.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/139.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/145.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/144.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/128.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/150.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/157.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/138.jpg'),
#  PosixPath('/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/134.jpg'),
#  ...]

# %%
labels = list(map(lambda x: os.path.split(os.path.split(x)[0])[1], filepaths))

filepaths = pd.Series(filepaths, name='Filepath').astype(str)
labels = pd.Series(labels, name='Label')

# Concatenate filepaths and labels
image_df = pd.concat([filepaths, labels], axis=1)

# %%
image_df
# Out:
#                                                Filepath      Label
# 0     /content/drive/MyDrive/Birds_data/train/ALBATR...  ALBATROSS
# 1     /content/drive/MyDrive/Birds_data/train/ALBATR...  ALBATROSS
# 2     /content/drive/MyDrive/Birds_data/train/ALBATR...  ALBATROSS
# 3     /content/drive/MyDrive/Birds_data/train/ALBATR...  ALBATROSS
# 4     /content/drive/MyDrive/Birds_data/train/ALBATR...  ALBATROSS
# ...                                                 ...        ...
# 1690  /content/drive/MyDrive/Birds_data/train/MYNA/1...       MYNA
# 1691  /content/drive/MyDrive/Birds_data/train/MYNA/1...       MYNA
# 1692  /content/drive/MyDrive/Birds_data/train/MYNA/1...       MYNA
# 1693  /content/drive/MyDrive/Birds_data/train/MYNA/1...       MYNA
# 1694  /content/drive/MyDrive/Birds_data/train/MYNA/1...       MYNA
#
# [1695 rows x 2 columns]

# %%
# # Get the labels and count
# label_counts = image_df['Label'].value_counts()[:10]

# plt.figure(figsize=(20, 6))
# sns.barplot(x=label_counts.index, y=label_counts.values, alpha=0.8, palette='dark:salmon_r')
# plt.title('Distribution of Top 10 Labels in Image Dataset', fontsize=16)
# plt.xlabel('Label', fontsize=14)
# plt.ylabel('Count', fontsize=14)
# plt.xticks(rotation=45)
# plt.show()

# %%
# Get the labels and count
label_counts = image_df['Label'].value_counts()[:10]
plt.figure(figsize=(26, 12))

sns.barplot(x=label_counts.index, y=label_counts.values, palette='viridis')
plt.title('List of birds v/s count')
plt.xlabel('Name of birds')
plt.ylabel('count')
plt.show()
# Out:
# <ipython-input-9-5b40b40d797a>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=label_counts.index, y=label_counts.values, palette='viridis')

# %%
# Get the labels and count

random_label_counts = label_counts.sample(frac=1, random_state=42)  # `random_state` for reproducibility

plt.figure(figsize=(26, 12))

# Use the randomized label counts for plotting
plt.plot(random_label_counts.index, random_label_counts.values, marker='o', linestyle='-', color='b')
plt.title('Random Ranking of Top 10 Birds v/s Count')
plt.xlabel('Name of Birds')
plt.ylabel('Count')
plt.xticks(rotation=45)  # Rotate the bird names for better readability
plt.grid(True)  # Add a grid for easier reading of values
plt.show()

# %%
random_index = np.random.randint(0, len(image_df),16)
fig, axes = plt.subplots(nrows=4, ncols=4, figsize=(10, 10),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(image_df.Filepath[random_index[i]]))
    ax.set_title(image_df.Label[random_index[i]])
plt.tight_layout()
plt.show()

# %%
def compute_ela_cv(path, quality):
    temp_filename = 'temp_file_name.jpeg'
    SCALE = 15
    orig_img = cv2.imread(path)
    edited_img = cv2.cvtColor(orig_img, cv2.COLOR_BGR2RGB)

    cv2.imwrite(temp_filename, edited_img, [cv2.IMWRITE_JPEG_QUALITY, quality])

    # read compressed image
    compressed_img = cv2.imread(temp_filename)

    # get absolute difference between img1 and img2 and multiply by scale
    diff = SCALE * cv2.absdiff(edited_img, compressed_img)
    return diff


# def convert_to_ela_image(path, quality):
#     temp_filename = 'temp_file_name.jpeg'
#     ela_filename = 'temp_ela.png'
#     image = Image.open(path).convert('RGB')
#     image.save(temp_filename, 'JPEG', quality = quality)
#     temp_image = Image.open(temp_filename)

#     ela_image = ImageChops.difference(image, temp_image)

#     extrema = ela_image.getextrema()
#     max_diff = max([ex[1] for ex in extrema])
#     if max_diff == 0:
#         max_diff = 1

#     scale = 255.0 / max_diff
#     ela_image = ImageEnhance.Brightness(ela_image).enhance(scale)

#     return ela_image


def random_sample(path, extension=None):
    if extension:
        items = Path(path).glob(f'*.{extension}')
    else:
        items = Path(path).glob(f'*')

    items = list(items)

    p = random.choice(items)
    return p.as_posix()

# %%
# View random sample from the dataset
p = random_sample('../content/drive/MyDrive/Birds_data/train/RED TAILED HAWK')
orig = cv2.imread(p)
edited_img = cv2.cvtColor(orig, cv2.COLOR_BGR2RGB)/255.0
# orig = cv2.cvtColor(orig, cv2.COLOR_BGR2RGB) / 255.0
# orig_img = cv2.imread(path)
# edited_img = cv2.cvtColor(orig_img, cv2.COLOR_BGR2RGB)
init_val = 100
columns = 3
rows = 3

fig=plt.figure(figsize=(15, 10))
for i in range(1, columns*rows +1):
    quality=init_val - (i-1) * 8
    img = compute_ela_cv(path=p, quality=quality)
    if i == 1:
        img = edited_img.copy()
        # img
    ax = fig.add_subplot(rows, columns, i)
    ax.title.set_text(f'q: {quality}')
    plt.imshow(img)
plt.show()

# %%
# Separate in train and test data
train_df, test_df = train_test_split(image_df, test_size=0.2, shuffle=True, random_state=42)

# %%
train_generator = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.efficientnet.preprocess_input,
    validation_split=0.2
)

test_generator = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.efficientnet.preprocess_input,
)

# %%
BATCH_SIZE = 16
TARGET_SIZE = (128, 128)

# %%
# Split the data into three categories.
train_images = train_generator.flow_from_dataframe(
    dataframe=train_df,
    x_col='Filepath',
    y_col='Label',
    target_size=TARGET_SIZE,
    color_mode='rgb',
    class_mode='categorical',
    batch_size=BATCH_SIZE,
    shuffle=True,
    seed=42,
    subset='training'
)

val_images = train_generator.flow_from_dataframe(
    dataframe=train_df,
    x_col='Filepath',
    y_col='Label',
    target_size=TARGET_SIZE,
    color_mode='rgb',
    class_mode='categorical',
    batch_size=BATCH_SIZE,
    shuffle=True,
    seed=42,
    subset='validation'
)

test_images = test_generator.flow_from_dataframe(
    dataframe=test_df,
    x_col='Filepath',
    y_col='Label',
    target_size=TARGET_SIZE,
    color_mode='rgb',
    class_mode='categorical',
    batch_size=BATCH_SIZE,
    shuffle=False
)
# Out:
# Found 1085 validated image filenames belonging to 10 classes.
# Found 271 validated image filenames belonging to 10 classes.
# Found 339 validated image filenames belonging to 10 classes.

# %%
# Data Augmentation Step
augment = tf.keras.Sequential([
  layers.experimental.preprocessing.Resizing(224,224),
  layers.experimental.preprocessing.Rescaling(1./255),
  layers.experimental.preprocessing.RandomFlip("horizontal"),
  layers.experimental.preprocessing.RandomRotation(0.1),
  layers.experimental.preprocessing.RandomZoom(0.1),
  layers.experimental.preprocessing.RandomContrast(0.1),
])

# %%
# Load the pretained model
pretrained_model = tf.keras.applications.efficientnet.EfficientNetB0(
    input_shape=(224, 224, 3),
    include_top=False,
    weights='imagenet',
    pooling='max'
)

pretrained_model.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 [==============================] - 0s 0us/step

# %%
# Create checkpoint callback
checkpoint_path = "birds_classification_model_checkpoint"
checkpoint_callback = ModelCheckpoint(checkpoint_path,
                                      save_weights_only=True,
                                      monitor="val_accuracy",
                                      save_best_only=True)

# Setup EarlyStopping callback to stop training if model's val_loss doesn't improve for 3 epochs
early_stopping = EarlyStopping(monitor = "val_loss", # watch the val loss metric
                               patience = 5,
                               restore_best_weights = True) # if val loss decreases for 3 epochs in a row, stop training

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=1e-6)

# %%
# !wget https://raw.githubusercontent.com/mrdbourke/tensorflow-deep-learning/main/extras/helper_functions.py

# Import series of helper functions for our notebook
from helper_functions import create_tensorboard_callback, plot_loss_curves, unzip_data, compare_historys, walk_through_dir, pred_and_plot
# Out:
# --2024-02-18 18:05:13--  https://raw.githubusercontent.com/mrdbourke/tensorflow-deep-learning/main/extras/helper_functions.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10246 (10K) [text/plain]
# Saving to: ‘helper_functions.py’
#
# helper_functions.py 100%[===================>]  10.01K  --.-KB/s    in 0s
#
# 2024-02-18 18:05:13 (65.3 MB/s) - ‘helper_functions.py’ saved [10246/10246]

# %%
inputs = pretrained_model.input
x = augment(inputs)

x = Dense(128, activation='relu')(pretrained_model.output)
x = Dropout(0.45)(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.45)(x)


outputs = Dense(10, activation='softmax')(x)

model = Model(inputs=inputs, outputs=outputs)

model.compile(
    optimizer=Adam(0.0001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

history = model.fit(
    train_images,
    steps_per_epoch=len(train_images),
    validation_data=val_images,
    validation_steps=len(val_images),
    epochs=150,
    callbacks=[
        early_stopping,
        create_tensorboard_callback("training_logs",
                                    "bird_classification"),
        checkpoint_callback,
        reduce_lr
    ]
)
# Out:
# Saving TensorBoard log files to: training_logs/bird_classification/20240218-180518
# Epoch 1/150
# 68/68 [==============================] - 266s 4s/step - loss: 3.3473 - accuracy: 0.1751 - val_loss: 1.4889 - val_accuracy: 0.6162 - lr: 1.0000e-04
# Epoch 2/150
# 68/68 [==============================] - 35s 519ms/step - loss: 1.9381 - accuracy: 0.3382 - val_loss: 1.0504 - val_accuracy: 0.8266 - lr: 1.0000e-04
# Epoch 3/150
# 68/68 [==============================] - 39s 570ms/step - loss: 1.5207 - accuracy: 0.4829 - val_loss: 0.7532 - val_accuracy: 0.8745 - lr: 1.0000e-04
# Epoch 4/150
# 68/68 [==============================] - 38s 564ms/step - loss: 1.1860 - accuracy: 0.5982 - val_loss: 0.5244 - val_accuracy: 0.9004 - lr: 1.0000e-04
# Epoch 5/150
# 68/68 [==============================] - 35s 516ms/step - loss: 1.0296 - accuracy: 0.6535 - val_loss: 0.3797 - val_accuracy: 0.9114 - lr: 1.0000e-04
# Epoch 6/150
# 68/68 [==============================] - 38s 565ms/step - loss: 0.7800 - accuracy: 0.7585 - val_loss: 0.2916 - val_accuracy: 0.9299 - lr: 1.0000e-04
# Epoch 7/150
# 68/68 [==============================] - 38s 567ms/step - loss: 0.6851 - accuracy: 0.7714 - val_loss: 0.2379 - val_accuracy: 0.9373 - lr: 1.0000e-04
# Epoch 8/150
# 68/68 [==============================] - 35s 505ms/step - loss: 0.5762 - accuracy: 0.8138 - val_loss: 0.2033 - val_accuracy: 0.9410 - lr: 1.0000e-04
# Epoch 9/150
# 68/68 [==============================] - 49s 719ms/step - loss: 0.4925 - accuracy: 0.8396 - val_loss: 0.1908 - val_accuracy: 0.9446 - lr: 1.0000e-04
# Epoch 10/150
# 68/68 [==============================] - 39s 568ms/step - loss: 0.4378 - accuracy: 0.8636 - val_loss: 0.1587 - val_accuracy: 0.9483 - lr: 1.0000e-04
# Epoch 11/150
# 68/68 [==============================] - 34s 498ms/step - loss: 0.3954 - accuracy: 0.8700 - val_loss: 0.1506 - val_accuracy: 0.9594 - lr: 1.0000e-04
# Epoch 12/150
# 68/68 [==============================] - 40s 584ms/step - loss: 0.3249 - accuracy: 0.8968 - val_loss: 0.1373 - val_accuracy: 0.9631 - lr: 1.0000e-04
# Epoch 13/150
# 68/68 [==============================] - 38s 567ms/step - loss: 0.3279 - accuracy: 0.8940 - val_loss: 0.1344 - val_accuracy: 0.9520 - lr: 1.0000e-04
# Epoch 14/150
# 68/68 [==============================] - 33s 493ms/step - loss: 0.2530 - accuracy: 0.9161 - val_loss: 0.1407 - val_accuracy: 0.9483 - lr: 1.0000e-04
# Epoch 15/150
# 68/68 [==============================] - 38s 558ms/step - loss: 0.2647 - accuracy: 0.9180 - val_loss: 0.1327 - val_accuracy: 0.9446 - lr: 1.0000e-04
# Epoch 16/150
# 68/68 [==============================] - 34s 494ms/step - loss: 0.2449 - accuracy: 0.9198 - val_loss: 0.1180 - val_accuracy: 0.9483 - lr: 1.0000e-04
# Epoch 17/150
# 68/68 [==============================] - 39s 576ms/step - loss: 0.2276 - accuracy: 0.9355 - val_loss: 0.1133 - val_accuracy: 0.9557 - lr: 1.0000e-04
# Epoch 18/150
# 68/68 [==============================] - 38s 563ms/step - loss: 0.1899 - accuracy: 0.9493 - val_loss: 0.1072 - val_accuracy: 0.9594 - lr: 1.0000e-04
# Epoch 19/150
# 68/68 [==============================] - 34s 495ms/step - loss: 0.1780 - accuracy: 0.9447 - val_loss: 0.1132 - val_accuracy: 0.9594 - lr: 1.0000e-04
# Epoch 20/150
# 68/68 [==============================] - 38s 561ms/step - loss: 0.1701 - accuracy: 0.9419 - val_loss: 0.1085 - val_accuracy: 0.9594 - lr: 1.0000e-04
# Epoch 21/150
# 68/68 [==============================] - 38s 565ms/step - loss: 0.1665 - accuracy: 0.9502 - val_loss: 0.1273 - val_accuracy: 0.9594 - lr: 1.0000e-04
# Epoch 22/150
# 68/68 [==============================] - 34s 501ms/step - loss: 0.1405 - accuracy: 0.9613 - val_loss: 0.1223 - val_accuracy: 0.9594 - lr: 2.0000e-05
# Epoch 23/150
# 68/68 [==============================] - 33s 489ms/step - loss: 0.1547 - accuracy: 0.9567 - val_loss: 0.1176 - val_accuracy: 0.9594 - lr: 2.0000e-05

# %%
# Save the model here
model.save('/content/drive/MyDrive/Colab Notebooks/my_model')

# %%
results = model.evaluate(test_images, verbose=0)

print("    Test Loss: {:.5f}".format(results[0]))
print("Test Accuracy: {:.2f}%".format(results[1] * 100))
# Out:
#     Test Loss: 0.07899
# Test Accuracy: 97.35%

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(accuracy))
plt.plot(epochs, accuracy, 'b', label='Training accuracy')
plt.plot(epochs, val_accuracy, 'r', label='Validation accuracy')

plt.title('Training and validation accuracy')
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')

plt.title('Training and validation loss')
plt.legend()
plt.show()

# %%
# Predict the label of the test_images
pred = model.predict(test_images)
pred = np.argmax(pred,axis=1)

# Map the label
labels = (train_images.class_indices)
labels = dict((v,k) for k,v in labels.items())
pred = [labels[k] for k in pred]

# Display the result
print(f'The first 5 predictions: {pred[:5]}')
# Out:
# 22/22 [==============================] - 13s 330ms/step
# The first 5 predictions: ['GRAY KINGBIRD', 'AMERICAN BITTERN', 'MYNA', 'GRAY KINGBIRD', 'RAZORBILL']

# %%
labels
# Out:
# {0: 'AFRICAN EMERALD CUCKOO',
#  1: 'AFRICAN PIED HORNBILL',
#  2: 'ALBATROSS',
#  3: 'AMERICAN BITTERN',
#  4: 'GOLDEN CHEEKED WARBLER',
#  5: 'GRAY KINGBIRD',
#  6: 'LONG-EARED OWL',
#  7: 'MYNA',
#  8: 'RAZORBILL',
#  9: 'RED TAILED HAWK'}

# %%
pred
# Out:
# ['GRAY KINGBIRD',
#  'AMERICAN BITTERN',
#  'MYNA',
#  'GRAY KINGBIRD',
#  'RAZORBILL',
#  'RED TAILED HAWK',
#  'LONG-EARED OWL',
#  'ALBATROSS',
#  'MYNA',
#  'AFRICAN EMERALD CUCKOO',
#  'MYNA',
#  'AFRICAN PIED HORNBILL',
#  'RAZORBILL',
#  'LONG-EARED OWL',
#  'RED TAILED HAWK',
#  'LONG-EARED OWL',
#  'LONG-EARED OWL',
#  'LONG-EARED OWL',
#  'AMERICAN BITTERN',
#  'AFRICAN PIED HORNBILL',
#  'LONG-EARED OWL',
#  'ALBATROSS',
#  'GOLDEN CHEEKED WARBLER',
#  'RAZORBILL',
#  'AFRICAN EMERALD CUCKOO',
#  'GOLDEN CHEEKED WARBLER',
#  'RAZORBILL',
#  'GOLDEN CHEEKED WARBLER',
#  'LONG-EARED OWL',
#  'RED TAILED HAWK',
#  'AFRICAN PIED HORNBILL',
#  'AMERICAN BITTERN',
#  'GRAY KINGBIRD',
#  'RED TAILED HAWK',
#  'RED TAILED HAWK',
#  'RED TAILED HAWK',
#  'GRAY KINGBIRD',
#  'GOLDEN CHEEKED WARBLER',
#  'AMERICAN BITTERN',
#  'MYNA',
#  'MYNA',
#  'AFRICAN PIED HORNBILL',
#  'AMERICAN BITTERN',
#  'AFRICAN EMERALD CUCKOO',
#  'MYNA',
#  'RED TAILED HAWK',
#  'LONG-EARED OWL',
#  'GOLDEN CHEEKED WARBLER',
#  'RAZORBILL',
#  'ALBATROSS',
#  'ALBATROSS',
#  'AMERICAN BITTERN',
#  'ALBATROSS',
#  'AFRICAN EMERALD CUCKOO',
#  'GRAY KINGBIRD',
#  'AMERICAN BITTERN',
#  'MYNA',
#  'MYNA',
#  'RAZORBILL',
#  'RED TAILED HAWK',
#  'AMERICAN BITTERN',
#  'GOLDEN CHEEKED WARBLER',
#  'MYNA',
#  'RED TAILED HAWK',
#  'RAZORBILL',
#  'GOLDEN CHEEKED WARBLER',
#  'MYNA',
#  'GOLDEN CHEEKED WARBLER',
#  'RAZORBILL',
#  'AMERICAN BITTERN',
#  'GOLDEN CHEEKED WARBLER',
#  'AMERICAN BITTERN',
#  'ALBATROSS',
#  'ALBATROSS',
#  'LONG-EARED OWL',
#  'GRAY KINGBIRD',
#  'AFRICAN EMERALD CUCKOO',
#  'AFRICAN PIED HORNBILL',
#  'MYNA',
#  'GOLDEN CHEEKED WARBLER',
#  'ALBATROSS',
#  'AMERICAN BITTERN',
#  'RAZORBILL',
#  'GOLDEN CHEEKED WARBLER',
#  'GOLDEN CHEEKED WARBLER',
#  'AFRICAN PIED HORNBILL',
#  'ALBATROSS',
#  'LONG-EARED OWL',
#  'MYNA',
#  'GRAY KINGBIRD',
#  'AMERICAN BITTERN',
#  'GOLDEN CHEEKED WARBLER',
#  'RED TAILED HAWK',
#  'AFRICAN EMERALD CUCKOO',
#  'RED TAILED HAWK',
#  'AFRICAN EMERALD CUCKOO',
#  'RED TAILED HAWK',
#  'GOLDEN CHEEKED WARBLER',
#  'AMERICAN BITTERN',
#  'AFRICAN PIED HORNBILL',
#  'AFRICAN EMERALD CUCKOO',
#  'AFRICAN PIED HORNBILL',
#  'GRAY KINGBIRD',
#  'LONG-EARED OWL',
#  'RAZORBILL',
#  'GOLDEN CHEEKED WARBLER',
#  'ALBATROSS',
#  'GOLDEN CHEEKED WARBLER',
#  'RAZORBILL',
#  'LONG-EARED OWL',
#  'RAZORBILL',
#  'ALBATROSS',
#  'AFRICAN EMERALD CUCKOO',
#  'RAZORBILL',
#  'AMERICAN BITTERN',
#  'RED TAILED HAWK',
#  'AFRICAN EMERALD CUCKOO',
#  'RAZORBILL',
#  'AMERICAN BITTERN',
#  'ALBATROSS',
#  'AFRICAN PIED HORNBILL',
#  'AFRICAN EMERALD CUCKOO',
#  'AFRICAN EMERALD CUCKOO',
#  'RAZORBILL',
#  'RAZORBILL',
#  'ALBATROSS',
#  'LONG-EARED OWL',
#  'MYNA',
#  'AFRICAN EMERALD CUCKOO',
#  'RED TAILED HAWK',
#  'ALBATROSS',
#  'AFRICAN EMERALD CUCKOO',
#  'GRAY KINGBIRD',
#  'RAZORBILL',
#  'GOLDEN CHEEKED WARBLER',
#  'GOLDEN CHEEKED WARBLER',
#  'AFRICAN PIED HORNBILL',
#  'AFRICAN PIED HORNBILL',
#  'AFRICAN EMERALD CUCKOO',
#  'AFRICAN EMERALD CUCKOO',
#  'GOLDEN CHEEKED WARBLER',
#  'GRAY KINGBIRD',
#  'AFRICAN EMERALD CUCKOO',
#  'GRAY KINGBIRD',
#  'AFRICAN PIED HORNBILL',
#  'MYNA',
#  'AFRICAN PIED HORNBILL',
#  'RED TAILED HAWK',
#  'MYNA',
#  'GOLDEN CHEEKED WARBLER',
#  'AFRICAN PIED HORNBILL',
#  'RAZORBILL',
#  'RED TAILED HAWK',
#  'AFRICAN EMERALD CUCKOO',
#  'ALBATROSS',
#  'AFRICAN PIED HORNBILL',
#  'MYNA',
#  'LONG-EARED OWL',
#  'RED TAILED HAWK',
#  'GOLDEN CHEEKED WARBLER',
#  'AFRICAN PIED HORNBILL',
#  'RED TAILED HAWK',
#  'AFRICAN EMERALD CUCKOO',
#  'AFRICAN EMERALD CUCKOO',
#  'AFRICAN PIED HORNBILL',
#  'MYNA',
#  'GRAY KINGBIRD',
#  'AFRICAN PIED HORNBILL',
#  'AFRICAN PIED HORNBILL',
#  'RED TAILED HAWK',
#  'AFRICAN PIED HORNBILL',
#  'RED TAILED HAWK',
#  'RED TAILED HAWK',
#  'RAZORBILL',
#  'LONG-EARED OWL',
#  'RED TAILED HAWK',
#  'AFRICAN PIED HORNBILL',
#  'ALBATROSS',
#  'ALBATROSS',
#  'GOLDEN CHEEKED WARBLER',
#  'AFRICAN PIED HORNBILL',
#  'MYNA',
#  'AMERICAN BITTERN',
#  'AMERICAN BITTERN',
#  'GRAY KINGBIRD',
#  'AFRICAN EMERALD CUCKOO',
#  'AFRICAN EMERALD CUCKOO',
#  'ALBATROSS',
#  'RAZORBILL',
#  'ALBATROSS',
#  'AFRICAN PIED HORNBILL',
#  'GOLDEN CHEEKED WARBLER',
#  'MYNA',
#  'RED TAILED HAWK',
#  'RED TAILED HAWK',
#  'RED TAILED HAWK',
#  'RED TAILED HAWK',
#  'AFRICAN EMERALD CUCKOO',
#  'ALBATROSS',
#  'RAZORBILL',
#  'MYNA',
#  'GRAY KINGBIRD',
#  'AFRICAN EMERALD CUCKOO',
#  'MYNA',
#  'AMERICAN BITTERN',
#  'RED TAILED HAWK',
#  'GRAY KINGBIRD',
#  'RAZORBILL',
#  'GRAY KINGBIRD',
#  'AFRICAN EMERALD CUCKOO',
#  'AMERICAN BITTERN',
#  'AFRICAN EMERALD CUCKOO',
#  'AFRICAN EMERALD CUCKOO',
#  'AFRICAN EMERALD CUCKOO',
#  'AMERICAN BITTERN',
#  'AFRICAN PIED HORNBILL',
#  'MYNA',
#  'RAZORBILL',
#  'ALBATROSS',
#  'AFRICAN EMERALD CUCKOO',
#  'RED TAILED HAWK',
#  'LONG-EARED OWL',
#  'GRAY KINGBIRD',
#  'AMERICAN BITTERN',
#  'RED TAILED HAWK',
#  'AFRICAN EMERALD CUCKOO',
#  'MYNA',
#  'MYNA',
#  'RED TAILED HAWK',
#  'GRAY KINGBIRD',
#  'MYNA',
#  'MYNA',
#  'RAZORBILL',
#  'GRAY KINGBIRD',
#  'GRAY KINGBIRD',
#  'GOLDEN CHEEKED WARBLER',
#  'LONG-EARED OWL',
#  'GRAY KINGBIRD',
#  'AFRICAN PIED HORNBILL',
#  'LONG-EARED OWL',
#  'LONG-EARED OWL',
#  'AFRICAN PIED HORNBILL',
#  'AMERICAN BITTERN',
#  'GOLDEN CHEEKED WARBLER',
#  'RED TAILED HAWK',
#  'RED TAILED HAWK',
#  'AMERICAN BITTERN',
#  'RED TAILED HAWK',
#  'RAZORBILL',
#  'GOLDEN CHEEKED WARBLER',
#  'RAZORBILL',
#  'AFRICAN PIED HORNBILL',
#  'GRAY KINGBIRD',
#  'RED TAILED HAWK',
#  'LONG-EARED OWL',
#  'RAZORBILL',
#  'AFRICAN PIED HORNBILL',
#  'AFRICAN PIED HORNBILL',
#  'RED TAILED HAWK',
#  'LONG-EARED OWL',
#  'LONG-EARED OWL',
#  'MYNA',
#  'GRAY KINGBIRD',
#  'AFRICAN EMERALD CUCKOO',
#  'RAZORBILL',
#  'AFRICAN PIED HORNBILL',
#  'GOLDEN CHEEKED WARBLER',
#  'LONG-EARED OWL',
#  'AFRICAN PIED HORNBILL',
#  'LONG-EARED OWL',
#  'RED TAILED HAWK',
#  'GOLDEN CHEEKED WARBLER',
#  'GOLDEN CHEEKED WARBLER',
#  'AMERICAN BITTERN',
#  'RED TAILED HAWK',
#  'MYNA',
#  'GRAY KINGBIRD',
#  'GOLDEN CHEEKED WARBLER',
#  'GRAY KINGBIRD',
#  'GOLDEN CHEEKED WARBLER',
#  'LONG-EARED OWL',
#  'RED TAILED HAWK',
#  'RED TAILED HAWK',
#  'MYNA',
#  'GRAY KINGBIRD',
#  'AMERICAN BITTERN',
#  'RED TAILED HAWK',
#  'AMERICAN BITTERN',
#  'LONG-EARED OWL',
#  'ALBATROSS',
#  'LONG-EARED OWL',
#  'RAZORBILL',
#  'RED TAILED HAWK',
#  'RED TAILED HAWK',
#  'AFRICAN EMERALD CUCKOO',
#  'AFRICAN PIED HORNBILL',
#  'RED TAILED HAWK',
#  'AFRICAN PIED HORNBILL',
#  'RAZORBILL',
#  'LONG-EARED OWL',
#  'AMERICAN BITTERN',
#  'RAZORBILL',
#  'RAZORBILL',
#  'GRAY KINGBIRD',
#  'AMERICAN BITTERN',
#  'RAZORBILL',
#  'AFRICAN PIED HORNBILL',
#  'MYNA',
#  'RAZORBILL',
#  'ALBATROSS',
#  'GOLDEN CHEEKED WARBLER',
#  'MYNA',
#  'ALBATROSS',
#  'ALBATROSS',
#  'LONG-EARED OWL',
#  'AMERICAN BITTERN',
#  'ALBATROSS',
#  'RED TAILED HAWK',
#  'ALBATROSS',
#  'RAZORBILL',
#  'MYNA',
#  'RAZORBILL',
#  'RED TAILED HAWK',
#  'RAZORBILL',
#  'GOLDEN CHEEKED WARBLER',
#  'RED TAILED HAWK',
#  'GRAY KINGBIRD',
#  'AFRICAN PIED HORNBILL',
#  'ALBATROSS',
#  'AFRICAN EMERALD CUCKOO',
#  'AFRICAN PIED HORNBILL',
#  'GRAY KINGBIRD',
#  'GRAY KINGBIRD',
#  'GOLDEN CHEEKED WARBLER',
#  'AFRICAN PIED HORNBILL',
#  'AFRICAN PIED HORNBILL',
#  'AFRICAN EMERALD CUCKOO',
#  'GRAY KINGBIRD',
#  'RAZORBILL']

# %%
  # Display 25 random pictures from the dataset with their labels
random_index = np.random.randint(0, len(test_df) - 1, 15)
fig, axes = plt.subplots(nrows=3, ncols=5, figsize=(25, 15),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(test_df.Filepath.iloc[random_index[i]]))
    if test_df.Label.iloc[random_index[i]] == pred[random_index[i]]:
        color = "green"
    else:
        color = "red"
    ax.set_title(f"True: {test_df.Label.iloc[random_index[i]]}\nPredicted: {pred[random_index[i]]}", color=color)
plt.show()
plt.tight_layout()

# %%
y_test = list(test_df.Label)
print(classification_report(y_test, pred))
# Out:
#                         precision    recall  f1-score   support
#
# AFRICAN EMERALD CUCKOO       1.00      0.97      0.99        35
#  AFRICAN PIED HORNBILL       0.97      1.00      0.99        37
#              ALBATROSS       0.96      1.00      0.98        27
#       AMERICAN BITTERN       1.00      1.00      1.00        29
# GOLDEN CHEEKED WARBLER       1.00      1.00      1.00        34
#          GRAY KINGBIRD       0.97      1.00      0.98        30
#         LONG-EARED OWL       0.97      0.90      0.93        31
#                   MYNA       1.00      0.97      0.98        33
#              RAZORBILL       0.97      0.95      0.96        39
#        RED TAILED HAWK       0.91      0.95      0.93        44
#
#               accuracy                           0.97       339
#              macro avg       0.98      0.97      0.97       339
#           weighted avg       0.97      0.97      0.97       339

# %%
report = classification_report(y_test, pred, output_dict=True)
df = pd.DataFrame(report).transpose()
df
# Out:
#                         precision    recall  f1-score     support
# AFRICAN EMERALD CUCKOO   1.000000  0.971429  0.985507   35.000000
# AFRICAN PIED HORNBILL    0.973684  1.000000  0.986667   37.000000
# ALBATROSS                0.964286  1.000000  0.981818   27.000000
# AMERICAN BITTERN         1.000000  1.000000  1.000000   29.000000
# GOLDEN CHEEKED WARBLER   1.000000  1.000000  1.000000   34.000000
# GRAY KINGBIRD            0.967742  1.000000  0.983607   30.000000
# LONG-EARED OWL           0.965517  0.903226  0.933333   31.000000
# MYNA                     1.000000  0.969697  0.984615   33.000000
# RAZORBILL                0.973684  0.948718  0.961039   39.000000
# RED TAILED HAWK          0.913043  0.954545  0.933333   44.000000
# accuracy                 0.973451  0.973451  0.973451    0.973451
# macro avg                0.975796  0.974761  0.974992  339.000000
# weighted avg             0.973961  0.973451  0.973420  339.000000

# %%
def get_img_array(img_path, size):
    img = tf.keras.preprocessing.image.load_img(img_path, target_size=size)
    array = tf.keras.preprocessing.image.img_to_array(img)
    # We add a dimension to transform our array into a "batch"
    # of size "size"
    array = np.expand_dims(array, axis=0)
    return array

def make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=None):
    # First, we create a model that maps the input image to the activations
    # of the last conv layer as well as the output predictions
    grad_model = tf.keras.models.Model(
        [model.inputs], [model.get_layer(last_conv_layer_name).output, model.output]
    )

# Then, we compute the gradient of the top predicted class for our input image
    # with respect to the activations of the last conv layer
    with tf.GradientTape() as tape:
        last_conv_layer_output, preds = grad_model(img_array)
        if pred_index is None:
            pred_index = tf.argmax(preds[0])
        class_channel = preds[:, pred_index]
    # This is the gradient of the output neuron (top predicted or chosen)
    # with regard to the output feature map of the last conv layer
    grads = tape.gradient(class_channel, last_conv_layer_output)

    # This is a vector where each entry is the mean intensity of the gradient
    # over a specific feature map channel
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    # We multiply each channel in the feature map array
    # by "how important this channel is" with regard to the top predicted class
    # then sum all the channels to obtain the heatmap class activation
    last_conv_layer_output = last_conv_layer_output[0]
    heatmap = last_conv_layer_output @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)

    # For visualization purpose, we will also normalize the heatmap between 0 & 1
    heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
    return heatmap.numpy()

def save_and_display_gradcam(img_path, heatmap, cam_path="cam.jpg", alpha=0.4):
    # Load the original image
    img = tf.keras.preprocessing.image.load_img(img_path)
    img = tf.keras.preprocessing.image.img_to_array(img)

    # Rescale heatmap to a range 0-255
    heatmap = np.uint8(255 * heatmap)

    # Use jet colormap to colorize heatmap
    jet = cm.get_cmap("jet")

    # Use RGB values of the colormap
    jet_colors = jet(np.arange(256))[:, :3]
    jet_heatmap = jet_colors[heatmap]

    # Create an image with RGB colorized heatmap
    jet_heatmap = tf.keras.preprocessing.image.array_to_img(jet_heatmap)
    jet_heatmap = jet_heatmap.resize((img.shape[1], img.shape[0]))
    jet_heatmap = tf.keras.preprocessing.image.img_to_array(jet_heatmap)

    # Superimpose the heatmap on original image
    superimposed_img = jet_heatmap * alpha + img
    superimposed_img = tf.keras.preprocessing.image.array_to_img(superimposed_img)
    # Save the superimposed image
    superimposed_img.save(cam_path)

    # Display Grad CAM
#     display(Image(cam_path))

    return cam_path

preprocess_input = tf.keras.applications.mobilenet_v2.preprocess_input
decode_predictions = tf.keras.applications.mobilenet_v2.decode_predictions

last_conv_layer_name = "top_conv"
img_size = (224,224, 3)

# Remove last layer's softmax
model.layers[-1].activation = None

# %%
# Display the part of the pictures used by the neural network to classify the pictures
fig, axes = plt.subplots(nrows=3, ncols=5, figsize=(15, 10),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    img_path = test_df.Filepath.iloc[random_index[i]]
    img_array = preprocess_input(get_img_array(img_path, size=img_size))
    heatmap = make_gradcam_heatmap(img_array, model, last_conv_layer_name)
    cam_path = save_and_display_gradcam(img_path, heatmap)
    ax.imshow(plt.imread(cam_path))
    ax.set_title(f"True: {test_df.Label.iloc[random_index[i]]}\nPredicted: {pred[random_index[i]]}")
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-32-d87a99df5208>:51: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   jet = cm.get_cmap("jet")

# %%
# model.save('/content/drive/MyDrive/Colab Notebooks/my_model')
from tensorflow.keras.models import load_model
model = load_model('/content/drive/MyDrive/Colab Notebooks/my_model')

# %%
def preprocess_image(image_path):
    img = tf.keras.preprocessing.image.load_img(image_path, target_size=(224, 224))
    img_array = tf.keras.preprocessing.image.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0)  # Create a batch
    img_array = tf.keras.applications.efficientnet.preprocess_input(img_array)
    return img_array

# %%
def predict_image(model, processed_image):
    predictions = model.predict(processed_image)
    predicted_class = np.argmax(predictions, axis=1)
    return predicted_class

# %%
labels_dict = {0: 'AFRICAN EMERALD CUCKOO',
 1: 'AFRICAN PIED HORNBILL',
 2: 'ALBATROSS',
 3: 'AMERICAN BITTERN',
 4: 'GOLDEN CHEEKED WARBLER',
 5: 'GRAY KINGBIRD',
 6: 'LONG-EARED OWL',
 7: 'MYNA',
 8: 'RAZORBILL',
 9: 'RED TAILED HAWK'}

# %%
# # Assuming 'filepaths' is already defined and contains the paths to your image files

# # Extract labels from filepaths
# labels = list(map(lambda x: os.path.split(os.path.split(x)[0])[1], filepaths))

# # Create a Series from labels
# labels_series = pd.Series(labels)

# # Convert the Series to a dictionary with numerical indices as keys and labels as values
# labels_dict = labels_series.to_dict()

# # Adjusting the dictionary to start indices from 0, if needed
# labels_dict = {i: label for i, label in enumerate(labels_dict.values())}

# %%
labels_dict
# Out:
# {0: 'AFRICAN EMERALD CUCKOO',
#  1: 'AFRICAN PIED HORNBILL',
#  2: 'ALBATROSS',
#  3: 'AMERICAN BITTERN',
#  4: 'GOLDEN CHEEKED WARBLER',
#  5: 'GRAY KINGBIRD',
#  6: 'LONG-EARED OWL',
#  7: 'MYNA',
#  8: 'RAZORBILL',
#  9: 'RED TAILED HAWK'}

# %%
def get_class_label(class_index):
    # Assuming you have a dictionary that maps class indices to labels
    # labels = {0: 'Class1', 1: 'Class2', ...}  # Fill in your actual labels
    return labels_dict[class_index]

# %%
# Load a new image
# image_path = '/content/drive/MyDrive/Birds_data/train/GRAY KINGBIRD/001.jpg'
# image_path = '/content/drive/MyDrive/Birds_data/train/RED TAILED HAWK/001.jpg'
image_path = '/content/drive/MyDrive/Birds_data/red_tailed_hawk.jpg'
processed_image = preprocess_image(image_path)

# Predict the image's class
predicted_class_index = predict_image(model, processed_image)

# Get the class label
class_label = get_class_label(predicted_class_index.item())

print(f'Predicted index: {predicted_class_index.item()}')
print(f'Predicted class: {class_label}')
# print({predicted_class_index.item(): 'Class label'})
# Out:
# 1/1 [==============================] - 0s 231ms/step
# Predicted index: 9
# Predicted class: RED TAILED HAWK
